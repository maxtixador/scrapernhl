# %% [markdown]
# # Getting Started with ScraperNHL
#
# Welcome to ScraperNHL! This notebook will teach you the basics of using the new unified API.
#
# ## What is ScraperNHL?
#
# ScraperNHL is a Python package for scraping hockey data from multiple leagues:
# - NHL (National Hockey League)
# - QMJHL (Quebec Major Junior Hockey League)
# - OHL (Ontario Hockey League)
# - WHL (Western Hockey League)
# - AHL (American Hockey League)
#
# ## New in Version 3.0
#
# The package has been completely redesigned with:
# - **Unified API**: One consistent interface for all leagues
# - **Simpler Design**: Easy functional API or flexible OOP API
# - **Better Performance**: Built-in caching and rate limiting
# - **Clean Data**: Automatic normalization and transformations

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Installation
#
# Make sure you have scrapernhl installed:
#
# ```bash
# pip install scrapernhl
# ```
#
# Or from source:
#
# ```bash
# pip install -e .
# ```

# %% [markdown]
# ## Method 1: Functional API (Recommended for Beginners)
#
# The simplest way to use ScraperNHL is with the `scrape()` function:

# %%
from scrapernhl import scrape
import pandas as pd

pd.set_option('display.max_columns', None)

# Get player stats from the QMJHL
stats = scrape('qmjhl', 'stats', season=90, position='skaters', limit=10)

print(f"Got {len(stats)} players")
print("\nTop 10 players:")
display(stats[['name', 'teamCode', 'G', 'A', 'PTS']].head(10))
# Out:
# Got 10 players
#
# Top 10 players:
#                    name teamCode   G   A  PTS
# 0    Radulov, Alexander      Que  61  91  152
# 1     Lascek, Stanislav      Chi  47  88  135
# 2     Boisclair, Maxime      Chi  70  60  130
# 3  Latendresse, Olivier      VdO  41  84  125
# 4     Desharnais, David      Chi  33  85  118
# 5          Aubin, Brent      Que  57  60  117
# 6      Brassard, Derick      Dru  44  72  116
# 7         Bourret, Alex      Sha  44  70  114
# 8      Dupuis, Philippe      Mon  32  76  108
# 9          Roy, Mathieu      Bat  50  54  104

# %%
stats.head()
# Out:
#   player_id                  name position rookie jerseyNumber teamCode  GP  \
# 0      9261    Radulov, Alexander       RW      0           22      Que  62
# 1      9734     Lascek, Stanislav       RW      0           17      Chi  64
# 2     10615     Boisclair, Maxime       LW      0           97      Chi  70
# 3      9732  Latendresse, Olivier        C      0           44      VdO  70
# 4     10288     Desharnais, David        C      0           15      Chi  63
#
#    GWG   G    S   Sh%   A  PTS  PTS/GP  +/-  PIM  PIM/GP  PPG  PPA  SHG  SHA  \
# 0    9  61  332  18.4  91  152    2.45   53  101    1.63   22   44   10    6
# 1    9  47  344  13.7  88  135    2.11   42   96    1.50   20   55    3    2
# 2   12  70  321  21.8  60  130    1.86   39   97    1.39   43   24    3    1
# 3    6  41  359  11.4  84  125    1.79    5   83    1.19   16   47    4    2
# 4    6  33  161  20.5  85  118    1.87   45   44    0.70   20   52    2    3
#
# ...

# %% [markdown]
# ### Available Data Types
#
# You can request different types of data:
#
# 1. **'pbp'** - Play-by-play data for a specific game
# 2. **'stats'** - Player statistics for skaters or goalies
# 3. **'schedule'** - Schedule for a team or entire league
# 4. **'roster'** - Team roster with player details
# 5. **'standings'** - Current league standings

# %%
# Get schedule for a team
schedule = scrape('ohl', 'schedule', season=83, team_id=16)

print(f"Games in schedule: {len(schedule)}")
display(schedule[['date', 'homeTeam', 'awayTeam']].head())
# Out:
# Games in schedule: 683
#         date             homeTeam             awayTeam
# 0 2025-09-18  North Bay Battalion      Oshawa Generals
# 1 2025-09-18   Peterborough Petes  Brampton Steelheads
# 2 2025-09-19  Brampton Steelheads      Niagara IceDogs
# 3 2025-09-19    Kitchener Rangers   Brantford Bulldogs
# 4 2025-09-19       London Knights    Owen Sound Attack

# %%
schedule.head()
# Out:
#   homeId awayId gameId   dateString homeScore awayScore gameStatus  \
# 0     19      4  28150  Thu, Sep 18         4         2      Final
# 1      6     18  28151  Thu, Sep 18         6         3      Final
# 2     18     20  28152  Fri, Sep 19         4         1      Final
# 3     10      1  28155  Fri, Sep 19         4         3   Final OT
# 4     14     11  28156  Fri, Sep 19         2         3   Final OT
#
#        homeCity    awayCity                            venue  \
# 0     North Bay      Oshawa  Boart Longyear Memorial Gardens
# 1  Peterborough    Brampton     Peterborough Memorial Centre
# 2      Brampton     Niagara                       CAA Centre
# 3     Kitchener   Brantford    Kitchener Memorial Auditorium
# 4        London  Owen Sound                Canada Life Place
#
#               homeTeam homeCode homeDivision  \
# 0  North Bay Battalion       NB            2
# 1   Peterborough Petes      PBO            1
# 2  Brampton Steelheads     BRAM            2
# ...

# %%
# Get league standings
standings = scrape('whl', 'standings', season=289)

print("WHL Standings:")
display(standings[['team_code', 'wins', 'losses', 'points']].head())
# Out:
# WHL Standings:
#   team_code wins losses points
# 0        PA   45      9     96
# 1       BDN   35     24     71
# 2       SAS   31     25     68
# 3       REG   23     29     53
# 4        MJ   21     33     49

# %%
standings.head()
# Out:
#   team_code wins losses ties ot_losses ot_wins shootout_wins shootout_losses  \
# 0        PA   45      9    0         5       3             2               1
# 1       BDN   35     24    0         1       4             2               0
# 2       SAS   31     25    0         4       4             2               2
# 3       REG   23     29    0         6       4             1               1
# 4        MJ   21     33    0         5       4             1               2
#
#   regulation_wins row points penalty_minutes   streak goals_for goals_against  \
# 0              40  43     96             686  0-1-0-0       273           153
# 1              29  33     71             778  0-1-0-0       241           215
# 2              25  29     68             660  1-0-0-0       204           207
# 3              18  22     53             682  0-1-0-0       212           249
# 4              16  20     49             623  1-0-0-0       212           269
#
# ...

# %%
scrape('whl', 'standings', season=285).head()
# Out:
#   team_code wins losses ties ot_losses ot_wins shootout_wins shootout_losses  \
# 0        PA   39     23    0         5       5             3               1
# 1       BDN   38     23    0         4       3             1               3
# 2       SAS   37     23    0         4       8             1               4
# 3        SC   35     30    0         1       6             4               2
# 4       REG   16     44    0         5       5             2               3
#
#   regulation_wins row points penalty_minutes   streak goals_for goals_against  \
# 0              31  36     84             776  5-0-0-0       253           228
# 1              34  37     83             750  2-0-0-0       255           213
# 2              28  36     82             550  0-1-1-0       235           218
# 3              25  31     73             756  0-1-0-0       240           256
# 4               9  14     40             765  0-2-0-0       170           285
#
# ...

# %%
scrape('qmjhl', 'standings', season=211).head()
# Out:
#   team_code wins losses ot_losses ot_wins shootout_wins shootout_losses row  \
# 0       Mon   44     10         2       3             5               2  39
# 1       Chi   43      9         3       1             1               2  42
# 2       NFL   35     20         2       5             2               1  33
# 3       Cha   29     20         2       5             3               6  26
# 4       Cap   27     21         2       1             3               9  24
#
#   points penalty_minutes   streak goals_for goals_against goals_diff  \
# 0     92             712  3-0-0-0       277           152        125
# 1     91             530  3-0-0-0       276           137        139
# 2     73             734  0-1-0-0       222           191         31
# 3     66             639  7-0-0-0       203           214        -11
# 4     65             585  0-2-0-1       160           184        -24
#
#   percentage overall_rank games_played  rank  past_10  \
# ...

# %%
scrape('qmjhl', 'roster', team=1,season=211).head()
# Out:
#   shoots                    birthplace player_id   birthdate tp_jersey_number  \
# 0      L        St.Andrews, NB, Canada     19539  2006-08-03                9
# 1      R           Ste-Foy, QC, Canada     19090  2005-09-22               10
# 2      L  Fairbanks, AK, United States     22466  2006-02-14               12
# 3      R    Norwell, MA, United States     20414  2007-02-16               14
# 4      R    Danbury, CT, United States     24195  2006-01-07               17
#
#   rookie position      h    w              name catches   lastName firstName  \
# 0      0        C  6'04"  225       Smith, Gabe     NaN      Smith      Gabe
# 1      0       RW  5'10"  183     Mercier, Alex     NaN    Mercier      Alex
# 2      0       LW  6'00"  191    Binkley, Simon     NaN    Binkley     Simon
# 3      1        C  6'01"  209     Mutryn, Teddy     NaN     Mutryn     Teddy
# 4      0       RW  6'00"  215  Wingfield, Jacob     NaN  Wingfield     Jacob
#
# ...

# %% [markdown]
# ## Method 2: Object-Oriented API (Advanced Usage)
#
# For more control, you can create a `HockeyScraper` object:
#
# ### ✨ NEW: Automatic Bootstrap Fetching
#
# When you create a scraper for non-NHL leagues, bootstrap data (teams, seasons, divisions) is **automatically fetched**!

# %%
from scrapernhl import HockeyScraper


for league in ['ohl', 'whl', 'qmjhl', 'ahl', 'pwhl']:
    # Create a scraper for the league
    scraper = HockeyScraper(league)
    season = scraper.config.default_season

    # Bootstrap data is automatically fetched!
    print(f"Bootstrap auto-fetched on initialization:")
    print(f"  League ID: {scraper.current_league_id}")
    print(f"  Season ID: {scraper.current_season_id}")
    print(f"  Teams: {len(scraper.teams)}")

    # Access team data easily
    print(f"\nFirst 5 teams:")
    for team in scraper.teams[:5]:
        print(f"  - {team['name']} (ID: {team['id']})")

    # Use methods to get data
    stats = scraper.player_stats(season=season, position='skaters', limit=15)
    schedule = scraper.schedule(season=season, team='all')  # 'all' or team_id
    standings = scraper.standings(season=season)

    print(f"\nData retrieved:")
    print(f"  Stats: {len(stats)} rows")
    print(f"  Schedule: {len(schedule)} games")
    print(f"  Standings: {len(standings)} teams")

    bootstrap_keys = scraper.bootstrap_data.keys()
    print(f"\nBootstrap data keys: {bootstrap_keys}")
# Out:
# Bootstrap auto-fetched on initialization:
#   League ID: 1
#   Season ID: 83
#   Teams: 20
#
# First 5 teams:
#   - Barrie Colts (ID: 7)
#   - Brampton Steelheads (ID: 18)
#   - Brantford Bulldogs (ID: 1)
#   - Erie Otters (ID: 8)
#   - Flint Firebirds (ID: 13)
#
# Data retrieved:
#   Stats: 15 rows
#   Schedule: 683 games
#   Standings: 20 teams
#
# Bootstrap data keys: dict_keys(['firebaseUrl', 'firebaseToken', 'firebaseApiKey', 'current_league_id', 'current_season_id', 'leagues', 'seasons', 'conferences', 'conferencesAll', 'divisions', 'divisionsAll', 'first_season_year', 'regularSeasons', 'playoffSeasons', 'teams', 'teamsNoAll', 'months', 'monthsAll', 'positions', 'goalies', 'rosterstatus', 'standingsFooter', 'rosterFooter', 'playerStatsFooter', 'showExpandedGoaliesOption', 'showRosterStatus', 'quickViews', 'dailySchedRefreshToggle', 'playerNoPicLogoOverride', 'svfConfig', 'svfLanguages', 'svfLang', 'player_shot_heat_map'])
# Bootstrap auto-fetched on initialization:
# ...

# %%
bs_data = {}
for league in ['ohl', 'whl', 'qmjhl', 'ahl', 'pwhl']:
    scraper = HockeyScraper(league)
    bs_data[league] = scraper.bootstrap_data
    
bs_data
# Out:
# {'ohl': {'firebaseUrl': 'leaguestat-b9523.firebaseio.com',
#   'firebaseToken': 'uwM69pPkdUhb0UuVAxM8IcA6pBAzATAxOc8979oJ',
#   'firebaseApiKey': 'AIzaSyBVn0Gr6zIFtba-hQy3StkifD8bb7Hi68A',
#   'current_league_id': '1',
#   'current_season_id': '83',
#   'leagues': [{'id': '2',
#     'name': 'Canadian Hockey League',
#     'short_name': 'CHL',
#     'code': 'chl',
#     'logo_image': ''},
#    {'id': '3',
#     'name': 'OHL All Star Game',
#     'short_name': 'All Star',
#     'code': 'allstar',
#     'logo_image': ''},
#    {'id': '1',
#     'name': 'Ontario Hockey League',
#     'short_name': 'OHL',
#     'code': 'ohl',
#     'logo_image': 'https://lscluster.hockeytech.com/download.php?client_code=ohl&file_path=img/logos/league-logo-1.jpg'},
#    {'id': '4',
#     'name': 'Tournaments',
#     'short_name': 'tourney',
#     'code': 'tourney',
#     'logo_image': ''}],
#   'seasons': [{'id': '84',
#     'name': '2025-26 OHL Top Prospects',
#     'default_sort': '',
# ...

# %%
import json

# save to a file
bs_data_json = json.dumps(bs_data, indent=4)
with open('bootstrap_data.json', 'w') as f:
    f.write(bs_data_json)

# %%
pd.json_normalize(scraper.bootstrap_data["seasons"])
# Out:
#   id                    name default_sort  start_date  hide_in_standings
# 0  8  2025-26 Regular Season               2025-11-21              False
# 1  7       2025-26 Preseason               2025-06-01               True
# 2  6           2025 Playoffs               2025-05-06              False
# 3  5  2024-25 Regular Season               2024-11-25              False
# 4  4       2024-25 Preseason               2024-11-01              False
# 5  3           2024 Playoffs               2024-05-06               True
# 6  1     2024 Regular Season               2024-01-01              False
# 7  2          2024 Preseason               2023-11-01              False

# %%
# Manually fetch bootstrap with specific parameters
ahl = HockeyScraper('ahl')

# Get bootstrap for a specific season
bootstrap = ahl.bootstrap(season='90', page_name='scorebar')

print(f"Manual bootstrap fetch:")
print(f"  Season ID: {bootstrap['current_season_id']}")
print(f"  Teams: {len(bootstrap['teams'])}")

# Note: NHL doesn't support bootstrap
try:
    nhl = HockeyScraper('nhl')
    nhl_bootstrap = nhl.bootstrap()
except NotImplementedError as e:
    print(f"\nNHL doesn't support bootstrap: {e}")
# Out:
# Manual bootstrap fetch:
#   Season ID: 90
#   Teams: 33
#
# NHL doesn't support bootstrap: Bootstrap endpoint not available for NHL.

# %% [markdown]
# ### Manual Bootstrap Method
#
# You can also manually fetch bootstrap with custom parameters:

# %%
# Bootstrap properties provide quick access to common data
pwhl = HockeyScraper('pwhl')

print("Convenience properties:")
print(f"  League ID: {pwhl.current_league_id}")
print(f"  Season ID: {pwhl.current_season_id}")
print(f"  Number of teams: {len(pwhl.teams)}")

# Full bootstrap data is also available
print(f"\nFull bootstrap has {len(pwhl.bootstrap_data)} keys:")
print(f"  Available keys: {list(pwhl.bootstrap_data.keys())[:10]}...")

# Access specific data from bootstrap
divisions = pwhl.bootstrap_data.get('divisions', [])
seasons = pwhl.bootstrap_data.get('regularSeasons', [])
print(f"\n  Divisions: {len(divisions)}")
print(f"  Regular seasons: {len(seasons)}")
# Out:
# Convenience properties:
#   League ID: 1
#   Season ID: 8
#   Number of teams: 8
#
# Full bootstrap has 34 keys:
#   Available keys: ['firebaseUrl', 'firebaseToken', 'firebaseApiKey', 'current_league_id', 'current_season_id', 'leagues', 'seasons', 'conferences', 'conferencesAll', 'divisions']...
#
#   Divisions: 1
#   Regular seasons: 3

# %% [markdown]
# ### Bootstrap Properties
#
# The scraper provides convenient properties for accessing bootstrap data:

# %% [markdown]
# ## Understanding the Output
#
# All methods return **pandas DataFrames** - this makes it easy to:
# - Filter and sort data
# - Export to CSV, Excel, or JSON
# - Perform analysis
# - Create visualizations

# %%
# Example: Filter and sort
stats = scrape('qmjhl', 'stats', season=90, position='skaters', limit=50)

# Get players with more than 20 goals
goal_scorers = stats[stats['G'] > 20].sort_values('G', ascending=False)

print(f"Found {len(goal_scorers)} players with 20+ goals")
display(goal_scorers[['playerName', 'teamCode', 'GP','G', 'A', 'PTS']].head(10))
# Out:
# Found 46 players with 20+ goals
#                   playerName teamCode  GP   G   A  PTS
# 2          Boisclair, Maxime      Chi  70  70  60  130
# 0         Radulov, Alexander      Que  62  61  91  152
# 13  Picard-Hooper, Alexandre      BaC  70  57  43  100
# 5               Aubin, Brent      Que  72  57  60  117
# 20          Goulet, Stéphane      Mon  67  51  42   93
# 9               Roy, Mathieu      Bat  65  50  54  104
# 14          Labelle, Olivier      Bat  67  50  50  100
# 1          Lascek, Stanislav      Chi  64  47  88  135
# 10            Aubin, Mathieu      Lew  70  47  56  103
# 22        Beauregard, Thomas      Bat  69  46  42   88

# %%
stats.head()
# Out:
#   player_id                  name position rookie jerseyNumber teamCode  GP  \
# 0      9261    Radulov, Alexander       RW      0           22      Que  62
# 1      9734     Lascek, Stanislav       RW      0           17      Chi  64
# 2     10615     Boisclair, Maxime       LW      0           97      Chi  70
# 3      9732  Latendresse, Olivier        C      0           44      VdO  70
# 4     10288     Desharnais, David        C      0           15      Chi  63
#
#    GWG   G    S   Sh%   A  PTS  PTS/GP  +/-  PIM  PIM/GP  PPG  PPA  SHG  SHA  \
# 0    9  61  332  18.4  91  152    2.45   53  101    1.63   22   44   10    6
# 1    9  47  344  13.7  88  135    2.11   42   96    1.50   20   55    3    2
# 2   12  70  321  21.8  60  130    1.86   39   97    1.39   43   24    3    1
# 3    6  41  359  11.4  84  125    1.79    5   83    1.19   16   47    4    2
# 4    6  33  161  20.5  85  118    1.87   45   44    0.70   20   52    2    3
#
# ...

# %% [markdown]
# ## Next Steps
#
# Now that you understand the basics, check out:
#
# 1. **02_nhl_data.ipynb** - Working with NHL data
# 2. **03_other_leagues.ipynb** - QMJHL, OHL, WHL, AHL examples
# 3. **04_advanced_features.ipynb** - Caching, rate limiting, transformations
#
# ## Summary
#
# - Use `scrape(league, data_type, **kwargs)` for simple queries
# - Use `HockeyScraper(league)` for object-oriented approach
# - **NEW:** Bootstrap data (teams, seasons, divisions) auto-fetched for non-NHL leagues
# - Access bootstrap via `scraper.teams`, `scraper.current_season_id`, etc.
# - All methods return pandas DataFrames
# - Supported leagues: NHL, PWHL, QMJHL, OHL, WHL, AHL
# - Data types: pbp, stats, schedule, roster, standings

# %% [markdown]
# ## League-Specific Parameters
#
# Each league and data type accepts specific parameters. Here are the most common ones:
#
# ### Player Stats
# - `season`: Season ID (e.g., 90 for QMJHL 2024-25)
# - `position`: 'skaters' or 'goalies'
# - `team`: Team ID or 'all'
# - `limit`: Number of results to return
#
# ### Schedule
# - `season`: Season ID
# - `team_id`: Team ID (-1 for all teams)
# - `month`: Month filter (-1 for all months)
#
# ### Play-by-Play
# - `game_id`: The game ID to scrape
# - `nhlify`: Apply NHL-style transformations (default: True)
#
# ### Roster
# - `team_id`: Team ID
# - `season`: Season ID
#
# ### Standings
# - `season`: Season ID

# %% [markdown]
# ## Error Handling
#
# ScraperNHL provides helpful error messages:

# %%
try:
    # This will fail - invalid data type
    data = scrape('qmjhl', 'invalid_type', season=90)
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: Invalid data_type: invalid_type

# %% [markdown]
# ## Next Steps
#
# Now that you understand the basics, check out:
#
# 1. **02_nhl_data.ipynb** - Working with NHL data
# 2. **03_other_leagues.ipynb** - QMJHL, OHL, WHL, AHL examples
# 3. **04_advanced_features.ipynb** - Caching, rate limiting, transformations
#
# ## Summary
#
# - Use `scrape(league, data_type, **kwargs)` for simple queries
# - Use `HockeyScraper(league)` for object-oriented approach
# - All methods return pandas DataFrames
# - Supported leagues: NHL, QMJHL, OHL, WHL, AHL
# - Data types: pbp, stats, schedule, roster, standings
