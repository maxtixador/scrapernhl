# %% [markdown]
# # AHL (American Hockey League) Examples
#
# This notebook demonstrates how to scrape and analyze data from the AHL using the HockeyTech API.
#
# **Note**: AHL uses the HockeyTech platform, which has a different data structure than the NHL API.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## 1. Get All AHL Teams
#
# Retrieve information about all AHL teams for the current season.

# %%
from scrapernhl.ahl.scrapers import scrapeTeams

# Get all AHL teams for the current season
teams = scrapeTeams()
print(f"Found {len(teams)} AHL teams")

# Display key information
if 'name' in teams.columns:
    display(teams.head(10))
else:
    display(teams.head(10))
# Out:
# Found 33 AHL teams
#     id                        name                   scrapedOn         source  \
# 0   -1                   All Teams  2026-01-11T16:07:55.174454  AHL Teams API
# 1  440          Abbotsford Canucks  2026-01-11T16:07:55.174454  AHL Teams API
# 2  402         Bakersfield Condors  2026-01-11T16:07:55.174454  AHL Teams API
# 3  413         Belleville Senators  2026-01-11T16:07:55.174454  AHL Teams API
# 4  317        Bridgeport Islanders  2026-01-11T16:07:55.174454  AHL Teams API
# 5  444           Calgary Wranglers  2026-01-11T16:07:55.174454  AHL Teams API
# 6  384          Charlotte Checkers  2026-01-11T16:07:55.174454  AHL Teams API
# 7  330              Chicago Wolves  2026-01-11T16:07:55.174454  AHL Teams API
# 8  373          Cleveland Monsters  2026-01-11T16:07:55.174454  AHL Teams API
# 9  445  Coachella Valley Firebirds  2026-01-11T16:07:55.174454  AHL Teams API
#
#     nickname team_code division_id  \
# 0        NaN       NaN         NaN
# 1    Canucks       ABB          25
# 2    Condors       BAK          25
# 3   Senators       BEL          16
# 4  Islanders       BRI          15
# 5  Wranglers       CGY          25
# 6   Checkers       CLT          15
# 7     Wolves       CHI          24
# 8   Monsters       CLE          16
# 9  Firebirds        CV          25
#
#                                                 logo
# 0                                                NaN
# 1  https://assets.leaguestat.com/ahl/logos/50x50/...
# 2  https://assets.leaguestat.com/ahl/logos/50x50/...
# 3  https://assets.leaguestat.com/ahl/logos/50x50/...
# 4  https://assets.leaguestat.com/ahl/logos/50x50/...
# 5  https://assets.leaguestat.com/ahl/logos/50x50/...
# 6  https://assets.leaguestat.com/ahl/logos/50x50/...
# 7  https://assets.leaguestat.com/ahl/logos/50x50/...
# 8  https://assets.leaguestat.com/ahl/logos/50x50/...
# 9  https://assets.leaguestat.com/ahl/logos/50x50/...

# %% [markdown]
# ## 2. Get Recent Games (Scorebar)
#
# The scorebar shows recent results and upcoming games with scores and status.

# %%
from scrapernhl.ahl.scrapers import scrapeScorebar

# Get recent games (7 days back, 7 days ahead)
scorebar = scrapeScorebar(days_ahead=7, days_back=7)
print(f"Found {len(scorebar)} games")

# Display key columns if they exist
columns_to_show = []
for col in ['GameDateISO8601', 'VisitorCode', 'HomeCode', 'VisitorGoals', 'HomeGoals', 'GameStatusString']:
    if col in scorebar.columns:
        columns_to_show.append(col)

if columns_to_show:
    display(scorebar[columns_to_show].head(10))
else:
    display(scorebar.head(10))
# Out:
# Found 0 games
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3. Get Full Season Schedule
#
# Retrieve the complete schedule for a team or the entire league.

# %%
from scrapernhl.ahl.scrapers import scrapeSchedule

# Get schedule for all teams
schedule = scrapeSchedule(team_id=-1, season=90)
print(f"Total games in schedule: {len(schedule)}")

# Show first few games
display(schedule.head(10))
# Out:
# ℹ Fetching AHL schedule (team=-1, season=90)...
# Total games in schedule: 1152
#    game_id date_with_day home_goal_count visiting_goal_count game_status  \
# 0  1027781   Fri, Oct 10               0                   1       Final
# 1  1027779   Fri, Oct 10               4                   3       Final
# 2  1027777   Fri, Oct 10               4                   1       Final
# 3  1027780   Fri, Oct 10               3                   4       Final
# 4  1027775   Fri, Oct 10               7                   4       Final
# 5  1027778   Fri, Oct 10               4                   5    Final OT
# 6  1027776   Fri, Oct 10               1                   2    Final OT
# 7  1027774   Fri, Oct 10               0                   5       Final
# 8  1027793   Sat, Oct 11               2                   3    Final OT
# 9  1027792   Sat, Oct 11               4                   1       Final
#
#      home_team_city visiting_team_city  game_report  game_sheet  \
# 0             Utica          Cleveland  Game Report  Game Sheet
# 1         Rochester            Toronto  Game Report  Game Sheet
# 2          Manitoba              Laval  Game Report  Game Sheet
# 3             Texas       Grand Rapids  Game Report  Game Sheet
# 4          Colorado            Calgary  Game Report  Game Sheet
# 5           Ontario             Tucson  Game Report  Game Sheet
# 6         Henderson         Abbotsford  Game Report  Game Sheet
# 7  Coachella Valley          San Diego  Game Report  Game Sheet
# 8             Utica          Cleveland  Game Report  Game Sheet
# 9           Toronto          Rochester  Game Report  Game Sheet
#
#   game_summary_long       flohockey_url  game_center  \
# 0      GAME SUMMARY  Watch on FloHockey  Game Center
# 1      GAME SUMMARY  Watch on FloHockey  Game Center
# 2      GAME SUMMARY  Watch on FloHockey  Game Center
# 3      GAME SUMMARY  Watch on FloHockey  Game Center
# 4      GAME SUMMARY  Watch on FloHockey  Game Center
# 5      GAME SUMMARY  Watch on FloHockey  Game Center
# 6      GAME SUMMARY  Watch on FloHockey  Game Center
# 7      GAME SUMMARY  Watch on FloHockey  Game Center
# 8      GAME SUMMARY  Watch on FloHockey  Game Center
# 9      GAME SUMMARY  Watch on FloHockey  Game Center
#
#                     scrapedOn            source tickets_url mobile_calendar
# 0  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 1  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 2  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 3  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 4  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 5  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 6  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 7  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 8  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN
# 9  2026-01-11T16:56:51.059673  AHL Schedule API         NaN             NaN

# %%
# Get schedule for a specific team (use first team from teams list)
if len(teams) > 0 and 'id' in teams.columns:
    team_id = teams.iloc[2]['id']
    team_name = teams.iloc[2].get('name', f"Team {team_id}")
    
    team_schedule = scrapeSchedule(team_id=team_id)
    print(f"\n{team_name} has {len(team_schedule)} games")
    display(team_schedule.head())
# Out:
# ℹ Fetching AHL schedule (team=402, season=90)...
# Bakersfield Condors has 72 games
#    game_id date_with_day home_goal_count visiting_goal_count game_status  \
# 0  1027789   Sat, Oct 11               7                   6       Final
# 1  1027811   Sat, Oct 18               2                   1       Final
# 2  1027826   Sun, Oct 19               5                   4    Final OT
# 3  1027852   Fri, Oct 24               5                   1       Final
# 4  1027864   Sat, Oct 25               1                   3       Final
#
#   home_team_city visiting_team_city  game_report  game_sheet  \
# 0       San Jose        Bakersfield  Game Report  Game Sheet
# 1    Bakersfield           San Jose  Game Report  Game Sheet
# 2    Bakersfield   Coachella Valley  Game Report  Game Sheet
# 3         Tucson        Bakersfield  Game Report  Game Sheet
# 4         Tucson        Bakersfield  Game Report  Game Sheet
#
#   game_summary_long       flohockey_url  game_center  \
# 0      GAME SUMMARY  Watch on FloHockey  Game Center
# 1      GAME SUMMARY  Watch on FloHockey  Game Center
# 2      GAME SUMMARY  Watch on FloHockey  Game Center
# 3      GAME SUMMARY  Watch on FloHockey  Game Center
# 4      GAME SUMMARY  Watch on FloHockey  Game Center
#
#                     scrapedOn            source tickets_url mobile_calendar
# 0  2026-01-11T16:57:28.670353  AHL Schedule API         NaN             NaN
# 1  2026-01-11T16:57:28.670353  AHL Schedule API         NaN             NaN
# 2  2026-01-11T16:57:28.670353  AHL Schedule API         NaN             NaN
# 3  2026-01-11T16:57:28.670353  AHL Schedule API         NaN             NaN
# 4  2026-01-11T16:57:28.670353  AHL Schedule API         NaN             NaN

# %% [markdown]
# ## 4. League Standings
#
# Get current standings with wins, losses, and points.

# %%
from scrapernhl.ahl.scrapers import scrapeStandings

# Get league standings
standings = scrapeStandings(context='overall', season=90)
print(f"Standings for {len(standings)} teams")

# Display standings
display(standings.head(10))
# Out:
# ℹ Fetching AHL standings (season=90, context=overall)...
# Standings for 32 teams
#   team_code wins losses ot_losses shootout_losses regulation_wins row points  \
# 0       WBS   23     10         1               2              20  22     49
# 1       PRO   24      7         1               0              19  24     49
# 2        LV   19     11         2               2              12  15     42
# 3       CLT   19     12         2               0              16  19     40
# 4       HER   17     14         1               0              14  16     35
# 5       SPR   13     15         4               2              12  13     32
# 6       HFD   12     16         4               1              11  12     29
# 7       BRI   13     17         2               1              10  11     29
# 8       LAV   22     12         0               1              18  20     45
# 9       SYR   19     13         2               1              18  19     41
#
#   penalty_minutes   streak goals_for goals_against games_remaining percentage  \
# 0             503  0-1-0-0       115            93              36      0.681
# 1             389  0-1-0-0       105            67              40      0.766
# 2             477  6-0-1-0        98            92              38      0.618
# 3             405  1-0-0-0        98            92              39      0.606
# 4             424  3-0-0-0        90            91              40      0.547
# 5             357  0-1-0-0        93           116              38      0.471
# 6             500  1-0-0-0        90           109              39      0.439
# 7             417  1-0-0-0        97           112              39      0.439
# 8             542  0-1-0-0       115            92              37      0.643
# 9             503  1-0-0-0       114            92              37      0.586
#
#   overall_rank games_played  rank  past_10                            name  \
# 0            2           36     1  4-4-0-2  Wilkes-Barre/Scranton Penguins
# 1            3           32     2  7-2-1-0               Providence Bruins
# 2            9           34     3  7-2-1-0          Lehigh Valley Phantoms
# 3           12           33     4  6-4-0-0              Charlotte Checkers
# 4           22           32     5  5-5-0-0                   Hershey Bears
# 5           26           34     6  5-4-1-0        Springfield Thunderbirds
# 6           28           33     7  4-5-0-1              Hartford Wolf Pack
# 7           29           33     8  3-6-1-0            Bridgeport Islanders
# 8            6           35     1  5-5-0-0                    Laval Rocket
# 9           10           35     2  4-4-1-1                 Syracuse Crunch
#
#                     scrapedOn             source
# 0  2026-01-11T16:57:41.292998  AHL Standings API
# 1  2026-01-11T16:57:41.292998  AHL Standings API
# 2  2026-01-11T16:57:41.292998  AHL Standings API
# 3  2026-01-11T16:57:41.292998  AHL Standings API
# 4  2026-01-11T16:57:41.292998  AHL Standings API
# 5  2026-01-11T16:57:41.292998  AHL Standings API
# 6  2026-01-11T16:57:41.292998  AHL Standings API
# 7  2026-01-11T16:57:41.292998  AHL Standings API
# 8  2026-01-11T16:57:41.292998  AHL Standings API
# 9  2026-01-11T16:57:41.292998  AHL Standings API

# %%
# Get standings by division
div_standings = scrapeStandings(context='overall', group_by='division', season=90)
print(f"\nDivision standings: {len(div_standings)} teams")
display(div_standings.head(15))
# Out:
# Division standings: 32 teams
#    team_code wins losses ot_losses shootout_losses regulation_wins row points  \
# 0        WBS   23     10         1               2              20  22     49
# 1        PRO   24      7         1               0              19  24     49
# 2         LV   19     11         2               2              12  15     42
# 3        CLT   19     12         2               0              16  19     40
# 4        HER   17     14         1               0              14  16     35
# 5        SPR   13     15         4               2              12  13     32
# 6        HFD   12     16         4               1              11  12     29
# 7        BRI   13     17         2               1              10  11     29
# 8        LAV   22     12         0               1              18  20     45
# 9        SYR   19     13         2               1              18  19     41
# 10       TOR   19     15         1               2              13  17     41
# 11       ROC   17     12         3               1              13  17     38
# 12       CLE   16     12         4               1              10  15     37
# 13       BEL   14     18         5               0              12  12     33
# 14       UTC   10     17         4               2               8   9     26
#
#    penalty_minutes   streak goals_for goals_against games_remaining  \
# 0              503  0-1-0-0       115            93              36
# 1              389  0-1-0-0       105            67              40
# 2              477  6-0-1-0        98            92              38
# 3              405  1-0-0-0        98            92              39
# 4              424  3-0-0-0        90            91              40
# 5              357  0-1-0-0        93           116              38
# 6              500  1-0-0-0        90           109              39
# 7              417  1-0-0-0        97           112              39
# 8              542  0-1-0-0       115            92              37
# 9              503  1-0-0-0       114            92              37
# 10             528  0-1-0-0       115           125              35
# 11             395  0-1-0-0       110           104              39
# 12             387  0-1-0-0        87            89              39
# 13             514  1-0-0-0       118           135              35
# 14             406  0-1-0-0        78           105              39
#
#    percentage overall_rank games_played  rank  past_10  \
# 0       0.681            2           36     1  4-4-0-2
# 1       0.766            3           32     2  7-2-1-0
# 2       0.618            9           34     3  7-2-1-0
# 3       0.606           12           33     4  6-4-0-0
# 4       0.547           22           32     5  5-5-0-0
# 5       0.471           26           34     6  5-4-1-0
# 6       0.439           28           33     7  4-5-0-1
# 7       0.439           29           33     8  3-6-1-0
# 8       0.643            6           35     1  5-5-0-0
# 9       0.586           10           35     2  4-4-1-1
# 10      0.554           11           37     3  6-3-0-1
# 11      0.576           14           33     4  4-3-2-1
# 12      0.561           19           33     5  6-3-1-0
# 13      0.446           24           37     6  3-4-3-0
# 14      0.394           30           33     7  5-3-1-1
#
#                               name                   scrapedOn  \
# 0   Wilkes-Barre/Scranton Penguins  2026-01-11T16:57:41.292998
# 1                Providence Bruins  2026-01-11T16:57:41.292998
# 2           Lehigh Valley Phantoms  2026-01-11T16:57:41.292998
# 3               Charlotte Checkers  2026-01-11T16:57:41.292998
# 4                    Hershey Bears  2026-01-11T16:57:41.292998
# 5         Springfield Thunderbirds  2026-01-11T16:57:41.292998
# 6               Hartford Wolf Pack  2026-01-11T16:57:41.292998
# 7             Bridgeport Islanders  2026-01-11T16:57:41.292998
# 8                     Laval Rocket  2026-01-11T16:57:41.292998
# 9                  Syracuse Crunch  2026-01-11T16:57:41.292998
# 10                 Toronto Marlies  2026-01-11T16:57:41.292998
# 11             Rochester Americans  2026-01-11T16:57:41.292998
# 12              Cleveland Monsters  2026-01-11T16:57:41.292998
# 13             Belleville Senators  2026-01-11T16:57:41.292998
# 14                    Utica Comets  2026-01-11T16:57:41.292998
#
#                source
# 0   AHL Standings API
# 1   AHL Standings API
# 2   AHL Standings API
# 3   AHL Standings API
# 4   AHL Standings API
# 5   AHL Standings API
# 6   AHL Standings API
# 7   AHL Standings API
# 8   AHL Standings API
# 9   AHL Standings API
# 10  AHL Standings API
# 11  AHL Standings API
# 12  AHL Standings API
# 13  AHL Standings API
# 14  AHL Standings API

# %% [markdown]
# ## 5. Team Roster
#
# Get the complete roster for a team including player positions and numbers.

# %%
from scrapernhl.ahl.scrapers import scrapeRoster

# Get roster for first team
if len(teams) > 0 and 'id' in teams.columns:
    team_id = teams.iloc[2]['id']
    team_name = teams.iloc[2].get('name', f"Team {team_id}")
    
    roster = scrapeRoster(team_id=int(team_id), season=90)
    print(f"{team_name} roster: {len(roster)} players")
    
    # Display roster
    display(roster.head(20))
# Out:
# Bakersfield Condors roster: 35 players
#    shoots            birthplace height_hyphenated player_id   birthdate  \
# 0       L        Blainville, QC               6-2      8890  2001-02-25
# 1       L      Tampere, Finland               6-3      8726  2002-08-08
# 2       L             Maple, ON               6-1      8846  2001-04-08
# 3       R  North Barrington, IL              5-11     10874  2002-01-01
# 4       L        Wood-Ridge, NJ               5-9      9728  1999-08-09
# 5       R       Wallaceburg, ON               5-9      5080  1993-01-04
# 6       L          Blenheim, ON               5-9      9229  2004-08-06
# 7       L        Moscow, Russia               6-2      9942  2003-03-12
# 8       R         Mansfield, MA              5-11     10624  2003-06-04
# 9       L         Rochester, MI               6-3      6780  1998-02-17
# 10      L          Edmonton, AB               5-9      8485  1999-04-27
# 11      L         Oulu, Finland               6-0     10876  2003-01-29
# 12      L            Whitby, ON               6-2      8696  2001-03-20
# 13      L           Amprior, ON               6-2     10595  2005-05-02
# 14      L     Coral Springs, FL              5-10     10599  2001-02-07
# 15      R           Atlanta, GA               6-0     10394  2003-09-09
# 16      L       Erding, Germany               6-2     10877  2002-03-22
# 17      L        Barrington, IL               6-2      9117  1999-05-06
# 18      L       Mantta, Finland               6-0     10879  1998-12-14
# 19      R            London, ON               6-5      6058  1994-01-21
#
#    tp_jersey_number position    w                name  \
# 0                 8        C  213          Sam Poulin
# 1                15       RW  209      Roby Järventie
# 2                19       LW  194      Daniel D’Amato
# 3                23       RW  176        Quinn Hutson
# 4                36        F  190       Matthew Brown
# 5                39       LW  185       Seth Griffith
# 6                41       RW  182    Brady Stonehouse
# 7                43       RW  200       Matvey Petrov
# 8                45        C  180        Matt Copponi
# 9                46       LW  217           Max Jones
# 10               52        C  185       James Hamblin
# 11               57        C  172     Viljami Marjala
# 12               63       RW  203        Ethan Keppen
# 13               64       LW  205  Connor Clattenburg
# 14               68       RW  170       Rhett Pitlick
# 15               70       RW  186        James Stefan
# 16               81        C  195       Josh Samanski
# 17                5        D  194       Tyler Inamoto
# 18               37        D  183       Atro Leppanen
# 19               44        D  217          Josh Brown
#
#                      scrapedOn          source  team_id catches role
# 0   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 1   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 2   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 3   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 4   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 5   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 6   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 7   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 8   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 9   2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 10  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 11  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 12  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 13  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 14  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 15  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 16  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 17  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 18  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN
# 19  2026-01-11T16:58:35.655254  AHL Roster API      402     NaN  NaN

# %% [markdown]
# ## 6. Player Statistics - Skaters
#
# Get scoring leaders and skater statistics.

# %%
from scrapernhl.ahl.scrapers import scrapeSkaterStats

# Get top scorers
skaters = scrapeSkaterStats(limit=25, sort='points', season=90)
print(f"Top {len(skaters)} scorers:")

# Display top scorers
display(skaters.head(25))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 4
#       1 from scrapernhl.ahl.scrapers import scrapeSkaterStats
#       3 # Get top scorers
# ----> 4 skaters = scrapeSkaterStats(limit=25, sort='points', season=90)
#       5 print(f"Top {len(skaters)} scorers:")
#       7 # Display top scorers
#
# File ~/nhl_scraper/scrapernhl/ahl/scrapers/wrappers.py:62, in scrapeSkaterStats(season, sort, team, limit, config)
#      46 """
#      47 Scrape AHL skater statistics as a DataFrame.
#      48
#    (...)     59     DataFrame with skater stats
#      60 """
#      61 # Import here to avoid circular imports
# ---> 62 from .complete_suite import scrapePlayerStats
#      63 return scrapePlayerStats(season=season, player_type='skater', sort=sort, limit=limit)
#
# ModuleNotFoundError: No module named 'scrapernhl.ahl.scrapers.teams_stats_roster'

# %%
# Get rookie leaders
from scrapernhl.ahl.api import get_skater_stats

rookies_data = get_skater_stats(rookies=1, limit=15, season=90)
if 'SiteKit' in rookies_data and 'PlayerStats' in rookies_data['SiteKit']:
    rookies = pd.DataFrame(rookies_data['SiteKit']['PlayerStats'])
    print(f"\nTop {len(rookies)} rookies:")
    display(rookies.head(15))

# %% [markdown]
# ## 7. Player Statistics - Goalies
#
# Get goalie statistics including wins, save percentage, and GAA.

# %%
from scrapernhl.ahl.scrapers import scrapeGoalieStats

# Get goalie stats sorted by save percentage
goalies = scrapeGoalieStats(limit=20, sort='save_pct', season=90)
print(f"Top {len(goalies)} goalies:")

# Display goalie stats
display(goalies.head(20))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 4
#       1 from scrapernhl.ahl.scrapers import scrapeGoalieStats
#       3 # Get goalie stats sorted by save percentage
# ----> 4 goalies = scrapeGoalieStats(limit=20, sort='save_pct', season=90)
#       5 print(f"Top {len(goalies)} goalies:")
#       7 # Display goalie stats
#
# File ~/nhl_scraper/scrapernhl/ahl/scrapers/wrappers.py:89, in scrapeGoalieStats(season, sort, team, limit, config)
#      73 """
#      74 Scrape AHL goalie statistics as a DataFrame.
#      75
#    (...)     86     DataFrame with goalie stats
#      87 """
#      88 # Import here to avoid circular imports
# ---> 89 from .complete_suite import scrapePlayerStats
#      90 return scrapePlayerStats(season=season, player_type='goalie', sort=sort, limit=limit)
#
# ModuleNotFoundError: No module named 'scrapernhl.ahl.scrapers.teams_stats_roster'

# %% [markdown]
# ## 8. Player Profiles
#
# Get detailed player information including bio, statistics, and career history.

# %%
from scrapernhl.ahl.scrapers.player import scrape_player_profile, scrape_player_career_stats

# Get a player ID from the top scorers
if len(skaters) > 0 and 'player_id' in skaters.columns:
    player_id = skaters.iloc[0]['player_id']
    player_name = skaters.iloc[0].get('name', f"Player {player_id}")
    
    # Get player profile
    profile = scrape_player_profile(player_id)
    print(f"Profile for {player_name}:")
    display(profile)
    
    # Get career stats
    career = scrape_player_career_stats(player_id)
    print(f"\nCareer stats for {player_name}:")
    display(career)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 from scrapernhl.ahl.scrapers.player import scrape_player_profile, scrape_player_career_stats
#       3 # Get a player ID from the top scorers
# ----> 4 if len(skaters) > 0 and 'player_id' in skaters.columns:
#       5     player_id = skaters.iloc[0]['player_id']
#       6     player_name = skaters.iloc[0].get('name', f"Player {player_id}")
#
# NameError: name 'skaters' is not defined

# %% [markdown]
# ## 9. Game Play-by-Play Data
#
# Scrape detailed play-by-play data for a completed game.

# %%
from scrapernhl.ahl.scrapers.games import scrape_game

# Find a completed game from scorebar
if len(scorebar) > 0:
    # Look for a game that's final
    completed = scorebar[scorebar.get('GameStatusString', '') == 'Final']
    
    if len(completed) > 0 and 'ID' in completed.columns:
        game_id = completed.iloc[0]['ID']
        print(f"Scraping game {game_id}...")
        
        try:
            pbp = scrape_game(game_id)
            print(f"Game has {len(pbp)} events")
            
            # Show event types
            if 'event' in pbp.columns:
                print("\nEvent counts:")
                print(pbp['event'].value_counts())
            
            # Show first events
            print("\nFirst 10 events:")
            display(pbp.head(10))
        except Exception as e:
            print(f"Error scraping game: {e}")
    else:
        print("No completed games found with valid IDs")
else:
    print("No games in scorebar")
# Out:
# No games in scorebar

# %% [markdown]
# ## 10. Compare Teams and Divisions
#
# Compare statistics between different teams and divisions.

# %%
# Get top players from two different teams
if len(teams) >= 2 and 'id' in teams.columns:
    team1_id = str(teams.iloc[0]['id'])
    team2_id = str(teams.iloc[1]['id'])
    team1_name = teams.iloc[0].get('name', f"Team {team1_id}")
    team2_name = teams.iloc[1].get('name', f"Team {team2_id}")
    
    team1_stats = scrapeSkaterStats(team=team1_id, limit=10)
    team2_stats = scrapeSkaterStats(team=team2_id, limit=10)
    
    print(f"{team1_name} top scorers:")
    display(team1_stats.head(10))
    
    print(f"\n{team2_name} top scorers:")
    display(team2_stats.head(10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 8
#       5 team1_name = teams.iloc[0].get('name', f"Team {team1_id}")
#       6 team2_name = teams.iloc[1].get('name', f"Team {team2_id}")
# ----> 8 team1_stats = scrapeSkaterStats(team=team1_id, limit=10)
#       9 team2_stats = scrapeSkaterStats(team=team2_id, limit=10)
#      11 print(f"{team1_name} top scorers:")
#
# File ~/nhl_scraper/scrapernhl/ahl/scrapers/wrappers.py:62, in scrapeSkaterStats(season, sort, team, limit, config)
#      46 """
#      47 Scrape AHL skater statistics as a DataFrame.
#      48
#    (...)     59     DataFrame with skater stats
#      60 """
#      61 # Import here to avoid circular imports
# ---> 62 from .complete_suite import scrapePlayerStats
#      63 return scrapePlayerStats(season=season, player_type='skater', sort=sort, limit=limit)
#
# ModuleNotFoundError: No module named 'scrapernhl.ahl.scrapers.teams_stats_roster'

# %% [markdown]
# ## 11. Advanced: Using the API Directly
#
# For more control, you can use the API functions directly.

# %%
from scrapernhl.ahl import api

# Get teams with API
teams_data = api.get_teams()
print(f"API returned: {type(teams_data)}")
print(f"Keys: {teams_data.keys() if isinstance(teams_data, dict) else 'N/A'}")

# Get standings with specific grouping
standings_data = api.get_standings(context='overall', group_by='division')
print(f"\nStandings data type: {type(standings_data)}")
# Out:
# API returned: <class 'dict'>
# Keys: dict_keys(['teams', 'teamsNoAll'])
#
# Standings data type: <class 'list'>

# %% [markdown]
# ## Bonus: Extract Data from Bootstrap
#
# The AHL API provides a bootstrap object with cached metadata.
# You can use helper functions to extract this data easily.

# %%
from scrapernhl.ahl.api import get_bootstrap
from scrapernhl.core.bootstrap_helpers import (
    get_leagues, get_seasons, get_regular_seasons, get_playoff_seasons,
    get_teams, get_teams_no_all, get_divisions, get_conferences,
    get_current_season_id, get_current_league_id
)

# Get bootstrap data
bootstrap = get_bootstrap()

# Extract various data
print('Bootstrap keys:', list(bootstrap.keys())[:10], '...')
print(f'\nCurrent Season ID: {get_current_season_id(bootstrap)}')
print(f'Current League ID: {get_current_league_id(bootstrap)}')

# Get teams (without 'All Teams' entry)
teams_from_bootstrap = get_teams_no_all(bootstrap)
print(f'\nTeams from bootstrap: {len(teams_from_bootstrap)} AHL teams')
display(teams_from_bootstrap.head())

# Get leagues
leagues = get_leagues(bootstrap)
if len(leagues) > 0:
    print(f'\nLeagues: {len(leagues)} league(s)')
    display(leagues)

# Get seasons
regular_seasons = get_regular_seasons(bootstrap)
if len(regular_seasons) > 0:
    print(f'\nRegular Seasons: {len(regular_seasons)} season(s)')
    display(regular_seasons.head())
# Out:
# Bootstrap keys: ['firebaseUrl', 'firebaseToken', 'firebaseApiKey', 'current_league_id', 'current_season_id', 'leagues', 'seasons', 'conferences', 'conferencesAll', 'divisions'] ...
#
# Current Season ID: 90
# Current League ID: 4
#
# Teams from bootstrap: 32 AHL teams
#     id                  name   nickname team_code division_id  \
# 0  440    Abbotsford Canucks    Canucks       ABB          25
# 1  402   Bakersfield Condors    Condors       BAK          25
# 2  413   Belleville Senators   Senators       BEL          16
# 3  317  Bridgeport Islanders  Islanders       BRI          15
# 4  444     Calgary Wranglers  Wranglers       CGY          25
#
#                                                 logo
# 0  https://assets.leaguestat.com/ahl/logos/50x50/...
# 1  https://assets.leaguestat.com/ahl/logos/50x50/...
# 2  https://assets.leaguestat.com/ahl/logos/50x50/...
# 3  https://assets.leaguestat.com/ahl/logos/50x50/...
# 4  https://assets.leaguestat.com/ahl/logos/50x50/...
# Leagues: 1 league(s)
#   id                    name short_name code  \
# 0  4  American Hockey League        AHL  ahl
#
#                                           logo_image
# 0  https://lscluster.hockeytech.com/download.php?...
# Regular Seasons: 22 season(s)
#    id                    name
# 0  90  2025-26 Regular Season
# 1  86  2024-25 Regular Season
# 2  81  2023-24 Regular Season
# 3  77  2022-23 Regular Season
# 4  73  2021-22 Regular Season

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the main AHL scraping functions:
#
# 1. **Teams**: `scrapeTeams()` - Get all AHL teams
# 2. **Schedule**: `scrapeSchedule()` - Get season schedule
# 3. **Scorebar**: `scrapeScorebar()` - Get recent/upcoming games
# 4. **Standings**: `scrapeStandings()` - Get league standings
# 5. **Roster**: `scrapeRoster()` - Get team rosters
# 6. **Player Stats**: `scrapeSkaterStats()` and `scrapeGoalieStats()` - Get player statistics
# 7. **Player Profiles**: `scrape_player_profile()` - Get detailed player info
# 8. **Play-by-Play**: `scrape_game()` - Get game events
#
# The AHL uses the HockeyTech platform, which is also used by PWHL, OHL, WHL, and QMJHL. The API structure is consistent across these leagues.
#
# For more information, see the [API documentation](../docs/api.md).
